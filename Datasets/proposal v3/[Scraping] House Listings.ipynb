# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import pandas as pd
from typing import Dict, List
import time
from urllib.parse import urljoin, urlparse, parse_qs, urlunparse

class LamudiScraper:
    def __init__(self):
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        self.base_url = "https://www.lamudi.com.ph"
        self.features_set = set()
        
    def get_listing_page(self, url: str) -> BeautifulSoup:
        response = requests.get(url, headers=self.headers)
        return BeautifulSoup(response.text, 'html.parser')
    
    def generate_page_url(self, base_url: str, page: int) -> str:
        parsed_url = urlparse(base_url)
        path = parsed_url.path.rstrip('/')  # Remove trailing slash
        new_path = f"{path}/page-{page}/"
        return urlunparse((parsed_url.scheme, parsed_url.netloc, new_path, 
                         parsed_url.params, parsed_url.query, parsed_url.fragment))
    
    def extract_listings_data(self, soup: BeautifulSoup, page_num: int) -> List[Dict]:
        listings = []
        listing_cells = soup.find_all('div', class_='ListingCell-content')
        total_listings = len(listing_cells)
        
        for idx, cell in enumerate(listing_cells, 1):
            listing_data = {}
            
            # Extract basic information
            title_elem = cell.find('h3', class_='ListingCell-KeyInfo-title')
            if not title_elem:  # Skip if no title found (likely invalid listing)
                continue
                
            listing_data['title'] = title_elem.text.strip()
            print(f"\nPage {page_num} - Property {idx}/{total_listings}")
            print(f"Title: {listing_data['title'][:100]}...")
            
            listing_info = cell.find('div', class_='ListingCell-AllInfo')
            if not listing_info:
                continue
                
            listing_data['listing_id'] = listing_info.get('data-sku', '')
            
            # Extract property details from ListingCell-AllInfo
            listing_data['bedrooms'] = self.extract_number_value(listing_info.get('data-bedrooms', ''))
            listing_data['bathrooms'] = self.extract_number_value(listing_info.get('data-bathrooms', ''))
            listing_data['floor_area'] = self.extract_number_value(listing_info.get('data-building_size', ''))
            listing_data['land_area'] = self.extract_number_value(listing_info.get('data-land_size', ''))
            
            # Extract coordinates from data-geo-point
            geo_point = listing_info.get('data-geo-point', '')
            if geo_point:
                try:
                    # Convert string "[longitude,latitude]" to list
                    coords = json.loads(geo_point)
                    listing_data['longitude'] = coords[0]
                    listing_data['latitude'] = coords[1]
                except (json.JSONDecodeError, IndexError):
                    pass
            
            link_elem = cell.find('a', class_='js-listing-link')
            if link_elem:
                listing_data['url'] = urljoin(self.base_url, link_elem['href'])
            
            # Extract price
            price_elem = cell.find('span', class_='PriceSection-FirstPrice')
            listing_data['price'] = price_elem.text.strip() if price_elem else None
            
            # Extract subdivision
            listing_data['subdivision'] = listing_info.get('data-subdivisionname', '')
            
            # Extract description
            desc_elem = cell.find('div', class_='ListingCell-shortDescription')
            listing_data['description'] = desc_elem.text.strip() if desc_elem else None
            
            # Get detailed data from property page
            print("Fetching detailed property information...")
            detailed_data = self.get_property_details(listing_data['url'])
            listing_data.update(detailed_data)
            print("Features found:", len(detailed_data.get('features', {})))
            
            listings.append(listing_data)
            time.sleep(1)  # Polite delay between requests
            
        return listings
    
    def get_property_details(self, url: str) -> Dict:
        soup = self.get_listing_page(url)
        details = {}
        
        # Find all script content
        page_content = str(soup)
        
        # Try to find property details using the exact patterns
        bathrooms_match = re.search(r'\"bathrooms\":\"(\d+)\"', page_content)
        bedrooms_match = re.search(r'\"bedrooms\":\"(\d+)\"', page_content)
        building_size_match = re.search(r'\"building_size\":(\d+)', page_content)
        land_size_match = re.search(r'\"land_size\":(\d+)', page_content)
        
        # Try to find coordinates using the exact pattern
        coords_match = re.search(r'GeoCoordinates\\\",\\\"latitude\\\":(\d+\.\d+),\\\"longitude\\\":(\d+\.\d+)', page_content)
        
        if bathrooms_match:
            details['bathrooms'] = int(bathrooms_match.group(1))
        if bedrooms_match:
            details['bedrooms'] = int(bedrooms_match.group(1))
        if building_size_match:
            details['floor_area'] = int(building_size_match.group(1))
        if land_size_match:
            details['land_area'] = int(land_size_match.group(1))
            
        if coords_match:
            details['latitude'] = float(coords_match.group(1))
            details['longitude'] = float(coords_match.group(2))
        
        # Extract features (simplified version without :1)
        features = []
        feature_items = soup.find_all('div', class_='FeatureGrid_featureItem__iwtDt')
        for item in feature_items:
            feature_text = item.find('p').text.strip()
            features.append(feature_text)
            self.features_set.add(feature_text)
            
        details['features'] = features
        
        print("Details found:", {k: v for k, v in details.items() if k != 'features'})
        
        return details
    
    def extract_number_value(self, value: str) -> int:
        if isinstance(value, (int, float)):
            return value
        match = re.search(r'\d+', str(value))
        return int(match.group()) if match else None
    
    def scrape_properties(self, url: str, num_pages: int = 1) -> pd.DataFrame:
        all_listings = []
        
        for page in range(1, num_pages + 1):
            print(f"\n{'='*50}")
            print(f"Scraping page {page} of {num_pages}")
            print(f"{'='*50}")
            page_url = self.generate_page_url(url, page) if page > 1 else url
            soup = self.get_listing_page(page_url)
            listings_data = self.extract_listings_data(soup, page)
            all_listings.extend(listings_data)
            
            # Add delay between pages
            if page < num_pages:
                time.sleep(2)
        
        # Convert to DataFrame
        df = pd.DataFrame(all_listings)
        
        # Create binary columns for features while keeping the original features dictionary
        for feature in self.features_set:
            df[f'has_{feature.lower().replace(" ", "_")}'] = df['features'].apply(
                lambda x: 1 if feature in x else 0 if isinstance(x, list) else 0
            )
        
        return df

# Usage example
if __name__ == "__main__":
    scraper = LamudiScraper()
    base_url = "https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/"
    
    # Scrape 5 pages (you can change this number)
    num_pages = 50
    df = scraper.scrape_properties(base_url, num_pages)
    
    # Save to CSV
    df.to_csv('lamudi_properties.csv', index=False)
# Out:
# ==================================================
# Scraping page 1 of 50
# ==================================================
#
# Page 1 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 1 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 1 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 1 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 1 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 1 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 1 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 1 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 1 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 1 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 1 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 1 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 1 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 1 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 1 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 1 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 1 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 1 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 1 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 1 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 1 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 1 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 1 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 1 - Property 24/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 1 - Property 25/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 1 - Property 26/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 1 - Property 27/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 1 - Property 28/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 1 - Property 29/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 1 - Property 30/30
# Title: Ready for Occupancy townhouse for sale near in Kalayaan Ave. 4 bedrooms...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# ==================================================
# Scraping page 2 of 50
# ==================================================
#
# Page 2 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 2 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 2 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 2 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 2 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 2 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 2 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 2 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 2 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 2 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 2 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 2 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 2 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 2 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 2 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 2 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 2 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 2 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 2 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 2 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 2 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 2 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 2 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 2 - Property 24/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 2 - Property 25/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 2 - Property 26/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 2 - Property 27/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 2 - Property 28/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 2 - Property 29/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 2 - Property 30/30
# Title: Ready for Occupancy townhouse for sale near in Kalayaan Ave. 4 bedrooms...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# ==================================================
# Scraping page 3 of 50
# ==================================================
#
# Page 3 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 3 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 3 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 3 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 3 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 3 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 3 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 3 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 3 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 3 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 3 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 3 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 3 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 3 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 3 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 3 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 3 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 3 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 3 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 3 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 3 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 3 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 3 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 3 - Property 24/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 3 - Property 25/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 3 - Property 26/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 3 - Property 27/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 3 - Property 28/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 3 - Property 29/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 3 - Property 30/30
# Title: Ready for Occupancy townhouse for sale near in Kalayaan Ave. 4 bedrooms...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# ==================================================
# Scraping page 4 of 50
# ==================================================
#
# Page 4 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 4 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 4 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 4 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 4 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 4 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 4 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 4 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 4 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 4 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 4 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 4 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 4 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 4 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 4 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 4 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 4 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 4 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 4 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 4 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 4 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 4 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 4 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 4 - Property 24/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 4 - Property 25/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 4 - Property 26/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 4 - Property 27/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 4 - Property 28/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 4 - Property 29/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 4 - Property 30/30
# Title: Ready for Occupancy townhouse for sale near in Kalayaan Ave. 4 bedrooms...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# ==================================================
# Scraping page 5 of 50
# ==================================================
#
# Page 5 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 5 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 5 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 5 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 5 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 5 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 5 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 5 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 5 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 5 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 5 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 5 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 5 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 5 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 5 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 5 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 5 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 5 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 5 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 5 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 5 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 5 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 5 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 5 - Property 24/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 5 - Property 25/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 5 - Property 26/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 5 - Property 27/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 5 - Property 28/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 5 - Property 29/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 5 - Property 30/30
# Title: Ready for Occupancy townhouse for sale near in Kalayaan Ave. 4 bedrooms...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# ==================================================
# Scraping page 6 of 50
# ==================================================
#
# Page 6 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 6 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 6 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 6 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 6 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 6 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 6 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 6 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 6 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 6 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 6 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 6 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 6 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 6 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 6 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 6 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 6 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 6 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 6 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 6 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 6 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 6 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 6 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 6 - Property 24/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 6 - Property 25/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 6 - Property 26/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 6 - Property 27/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 6 - Property 28/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 6 - Property 29/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 6 - Property 30/30
# Title: Ready for Occupancy townhouse for sale near in Kalayaan Ave. 4 bedrooms...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# ==================================================
# Scraping page 7 of 50
# ==================================================
#
# Page 7 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 7 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 7 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 7 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 7 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 7 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 7 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 7 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 7 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 7 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 7 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 7 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 7 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 7 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 7 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 7 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 7 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 7 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 7 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 7 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 7 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 7 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 7 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 7 - Property 24/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 7 - Property 25/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 7 - Property 26/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 7 - Property 27/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 7 - Property 28/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 7 - Property 29/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 7 - Property 30/30
# Title: Ready for Occupancy townhouse for sale near in Kalayaan Ave. 4 bedrooms...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# ==================================================
# Scraping page 8 of 50
# ==================================================
#
# Page 8 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 8 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 8 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 8 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 8 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 8 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 8 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 8 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 8 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 8 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 8 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 8 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 8 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 8 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 8 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 8 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 8 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 8 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 8 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 8 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 8 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 8 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 8 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 8 - Property 24/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 8 - Property 25/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 8 - Property 26/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 8 - Property 27/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 8 - Property 28/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 8 - Property 29/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 8 - Property 30/30
# Title: Ready for Occupancy townhouse for sale near in Kalayaan Ave. 4 bedrooms...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# ==================================================
# Scraping page 9 of 50
# ==================================================
#
# Page 9 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 9 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 9 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 9 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 9 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 9 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 9 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 9 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 9 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 9 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 9 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 9 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 9 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 9 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 9 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# ...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 48 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 48 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 48 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 48 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 48 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 48 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 48 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 48 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 48 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 48 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 48 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 48 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 48 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 48 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 48 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 48 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 48 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 48 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 48 - Property 24/30
# Title: Old house in Corner Lot 50m away from St. Lukes QC for SALE...
# Fetching detailed property information...
# Details found: {}
# Features found: 0
#
# Page 48 - Property 25/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 48 - Property 26/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 48 - Property 27/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 48 - Property 28/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 48 - Property 29/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 48 - Property 30/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# ==================================================
# Scraping page 49 of 50
# ==================================================
#
# Page 49 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 49 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 49 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 49 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 49 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 49 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 49 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 49 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 49 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 49 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 49 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 49 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 49 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 49 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 49 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 49 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 49 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 49 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 49 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 49 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 49 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 49 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 49 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 49 - Property 24/30
# Title: Old house in Corner Lot 50m away from St. Lukes QC for SALE...
# Fetching detailed property information...
# Details found: {}
# Features found: 0
#
# Page 49 - Property 25/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 49 - Property 26/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 49 - Property 27/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 49 - Property 28/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 49 - Property 29/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 49 - Property 30/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# ==================================================
# Scraping page 50 of 50
# ==================================================
#
# Page 50 - Property 1/30
# Title: Brand New House and Lot For Sale near New Manila QC and San Juan Greenhills...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 50 - Property 2/30
# Title: 7.4 m Brand New SINGLE House and LOT in NEW HAVEN Subdivision Qc - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 13
#
# Page 50 - Property 3/30
# Title: 5.1m Brand NEW 3 Bedrooms House and Lot Pre - Selling in North Olmpus Subd -JOJO...
# Fetching detailed property information...
# Details found: {}
# Features found: 18
#
# Page 50 - Property 4/30
# Title: North Olympus Brand NEW House and LOT For Sale Pre - Selling - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 22
#
# Page 50 - Property 5/30
# Title: CORNER LOT 3 Bedrooms Brand NEW House and LOT For Sale in North Olympus Subd Qc...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 50 - Property 6/30
# Title: 100 Sqm Single  House and Lot For Sale in New Haven Subdivision QC - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 50 - Property 7/30
# Title: Pre Selling Brand New House and Lot Fot Sale in NEW HEAVEN Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 15
#
# Page 50 - Property 8/30
# Title: New Haven Brand NEW Townhouse For Sale Near Sm Fairview - Jojo Obra...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 50 - Property 9/30
# Title: 3 Bedroom Brandnew House and Lot For Sale in NEW HAVEN Subd., Quezon City - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 50 - Property 10/30
# Title: ELEGANT BRAND New  House and LOT For Sale IN New Heaven Subdivision Qc - Jojo...
# Fetching detailed property information...
# Details found: {}
# Features found: 16
#
# Page 50 - Property 11/30
# Title: For Sale: Brand New 3-Storey House in Mira Nila Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 6
#
# Page 50 - Property 12/30
# Title: Single Detached House and lot for sale in New Manila Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 50 - Property 13/30
# Title: 5 BR Modern Classy House for Sale in Casa Milan, North Fairview, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 31
#
# Page 50 - Property 14/30
# Title: Capitol Homes Old Balara, QC Brand-New House and Lot with Pool for Sale...
# Fetching detailed property information...
# Details found: {}
# Features found: 19
#
# Page 50 - Property 15/30
# Title: 4 BR Modern Elegant House for Sale in Brittany Subd. Novaliches, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 50 - Property 16/30
# Title: 4BR Fully Furnished Modern House for Sale in Filinvest, BatasanHills,Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 23
#
# Page 50 - Property 17/30
# Title: Compound townhouse for sale in Sikatuna Village 4 Bedroom 4 Toilet&Bath...
# Fetching detailed property information...
# Details found: {}
# Features found: 12
#
# Page 50 - Property 18/30
# Title: For Sale: Spacious and Well Maintained House and Lot in Congressional Village...
# Fetching detailed property information...
# Details found: {}
# Features found: 8
#
# Page 50 - Property 19/30
# Title: For Sale: 2-Storey Townhouse with Attic in Philam Homes Village, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 50 - Property 20/30
# Title: For Sale: House and Lot in BF Homes, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 4
#
# Page 50 - Property 21/30
# Title: Brand New New Manila Townhouse For Sale near Robinsons Magnolia Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 17
#
# Page 50 - Property 22/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 50 - Property 23/30
# Title: House for Sale in Quezon City near Robinsons Magnolia...
# Fetching detailed property information...
# Details found: {}
# Features found: 10
#
# Page 50 - Property 24/30
# Title: Old house in Corner Lot 50m away from St. Lukes QC for SALE...
# Fetching detailed property information...
# Details found: {}
# Features found: 0
#
# Page 50 - Property 25/30
# Title: For Sale: House and Lot in Ayala Heights, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 50 - Property 26/30
# Title: 3 BEDROOM Brand NEW TOWNHOUSE FOR SALE IDEAL SUBDIVISION, QC near MRT 7...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 50 - Property 27/30
# Title: 3 bedrooms House and Lot for sale in Woodland Grove, Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 1
#
# Page 50 - Property 28/30
# Title: Townhouse for sale in Quezon City near Philippine Heart Center...
# Fetching detailed property information...
# Details found: {}
# Features found: 3
#
# Page 50 - Property 29/30
# Title: House and Lot For Sale in Quezon City...
# Fetching detailed property information...
# Details found: {}
# Features found: 14
#
# Page 50 - Property 30/30
# Title: Townhouse for Sale in Quezon City near Philippine Heart Center 4BR & 6 T&B...
# Fetching detailed property information...
# Details found: {}
# Features found: 4

# %%
import pandas as pd

df = pd.read_csv("lamudi_properties.csv")
df.head()

print(df.columns.tolist())
# Out:
# ['title', 'listing_id', 'bedrooms', 'bathrooms', 'floor_area', 'land_area', 'longitude', 'latitude', 'url', 'price', 'subdivision', 'description', 'features', 'has_cctv', 'has_alarm_system', 'has_parks', 'has_courtyard', 'has_multi-purpose_lawn', 'has_secure_parking', 'has_fully_fenced', 'has_fire_alarm', 'has_tennis_court', 'has_remote_garage', 'has_function_area', 'has_wi-fi', 'has_attic', 'has_lanai', 'has_ensuite', 'has_volleyball_court', 'has_terrace', 'has_storage_room', 'has_sports_facilities', 'has_air_conditioning', 'has_basketball_court', 'has_study_room', "has_driver's_room", 'has_garden', 'has_playground', "has_maid's_room", 'has_helipad', 'has_jogging_path', 'has_smoke_detector', 'has_carport', 'has_open_space', 'has_badminton_court', 'has_built-in_wardrobes', 'has_bar', 'has_open_car_spaces', 'has_landscaped_garden', 'has_entertainment_room', 'has_parking_lot', 'has_powder_room', 'has_24-hour_security', 'has_clubhouse', 'has_maids_room', 'has_garage', 'has_shower_rooms', 'has_swimming_pool', 'has_balcony']

# %%
# Create a copy of the original dataframe
df_standardized = df.copy()

# Dictionary mapping for features that need to be combined or renamed
feature_mapping = {
    # Security/Safety features
    'Security': ['has_cctv', 'has_24-hour_security'],
    'Alarm': ['has_alarm_system'],
    
    # Outdoor/Recreational features
    'Tennis court': ['has_tennis_court'],
    'Swimming pool': ['has_swimming_pool'],
    'Balcony': ['has_balcony', 'has_lanai'],  # Added has_lanai
    'Garden': ['has_garden'],
    'Terrace': ['has_terrace'],
    "Children's area": ['has_playground'],
    
    # Storage/Utility features
    'Built-in wardrobe': ['has_built-in_wardrobes'],
    'Utility room': ['has_storage_room'],
    
    # Parking features
    'Car park': ['has_carport', 'has_garage', 'has_parking_lot', 'has_open_car_spaces', 'has_remote_garage'],  # Added has_remote_garage
    
    # Climate Control
    'Air conditioning': ['has_air_conditioning'],
    
    # Internet/Technology
    'Internet': ['has_wi-fi'],

    # Feature list
    'facilities' : ['features']
}

# Create new columns based on the mapping
for new_feature, old_features in feature_mapping.items():
    # Create the new column by combining the old ones using OR operation
    df_standardized[new_feature] = df_standardized[old_features].any(axis=1).astype(int)

# Get list of all original columns that were used in the mapping
columns_to_drop = []
for old_features in feature_mapping.values():
    columns_to_drop.extend(old_features)

# Drop the original columns
df_standardized = df_standardized.drop(columns=columns_to_drop)

# Print the remaining columns to verify
print("Remaining columns:", sorted(df_standardized.columns.tolist()))
# Out:
# Remaining columns: ['Air conditioning', 'Alarm', 'Balcony', 'Built-in wardrobe', 'Car park', "Children's area", 'Garden', 'Internet', 'Security', 'Swimming pool', 'Tennis court', 'Terrace', 'Utility room', 'bathrooms', 'bedrooms', 'description', 'facilities', 'floor_area', 'has_attic', 'has_badminton_court', 'has_bar', 'has_basketball_court', 'has_clubhouse', 'has_courtyard', "has_driver's_room", 'has_ensuite', 'has_entertainment_room', 'has_fire_alarm', 'has_fully_fenced', 'has_function_area', 'has_helipad', 'has_jogging_path', 'has_landscaped_garden', "has_maid's_room", 'has_maids_room', 'has_multi-purpose_lawn', 'has_open_space', 'has_parks', 'has_powder_room', 'has_secure_parking', 'has_shower_rooms', 'has_smoke_detector', 'has_sports_facilities', 'has_study_room', 'has_volleyball_court', 'land_area', 'latitude', 'listing_id', 'longitude', 'price', 'subdivision', 'title', 'url']

# %%
# Get list of columns that start with 'has_'
columns_to_drop = [col for col in df_standardized.columns if col.startswith('has_')]

# Drop these columns
df_standardized = df_standardized.drop(columns=columns_to_drop)

# Print remaining columns to verify
print("Remaining columns in df:", sorted(df_standardized.columns.tolist()))
# Out:
# Remaining columns in df: ['Air conditioning', 'Alarm', 'Balcony', 'Built-in wardrobe', 'Car park', "Children's area", 'Garden', 'Internet', 'Security', 'Swimming pool', 'Tennis court', 'Terrace', 'Utility room', 'bathrooms', 'bedrooms', 'description', 'facilities', 'floor_area', 'land_area', 'latitude', 'listing_id', 'longitude', 'price', 'subdivision', 'title', 'url']

# %%
dot = pd.read_csv("[dec 1] dot_house.csv")
print(dot.columns.tolist())
# Out:
# ['title', 'location', 'price', 'price_per_sqm', 'url', 'listing_id', 'bedrooms', 'bathrooms', 'floor_area', 'land_area', 'floor', 'name', 'latitude', 'longitude', 'address', 'facilities', 'Access for the disabled', 'Air conditioning', 'Alarm', 'Balcony', 'Built-in kitchen', 'Built-in wardrobe', 'Car park', "Children's area", 'Cistern', 'Concierge', 'Electricity', 'Elevator', 'Equipped kitchen', 'Garden', 'Grill', 'Guardhouse', 'Gym', 'Heating', 'Hot Tub', 'Internet', 'Library', 'Natural gas', 'Office', 'Panoramic view', 'Patio', 'Roof garden', 'Sauna', 'Security', 'Swimming pool', 'Tennis court', 'Terrace', 'Utility room', 'Video cable', 'Water', 'Fireplace', 'Cellar']

# %%
# List of columns to remove
columns_to_remove = [
    'Access for the disabled',
    'Built-in kitchen',
    'Cistern',
    'Concierge',
    'Electricity',
    'Elevator',
    'Equipped kitchen',
    'Grill',
    'Guardhouse',
    'Gym',
    'Heating',
    'Hot Tub',
    'Library',
    'Natural gas',
    'Office',
    'Panoramic view',
    'Patio',
    'Roof garden',
    'Sauna',
    'Video cable',
    'Water',
    'Fireplace',
    'Cellar',
    'price_per_sqm'
]

# Drop these columns from dot
dot = dot.drop(columns=columns_to_remove)

# Print remaining columns to verify
print("Remaining columns in dot:", sorted(dot.columns.tolist()))
# Out:
# Remaining columns in dot: ['Air conditioning', 'Alarm', 'Balcony', 'Built-in wardrobe', 'Car park', "Children's area", 'Garden', 'Internet', 'Security', 'Swimming pool', 'Tennis court', 'Terrace', 'Utility room', 'address', 'bathrooms', 'bedrooms', 'facilities', 'floor', 'floor_area', 'land_area', 'latitude', 'listing_id', 'location', 'longitude', 'name', 'price', 'title', 'url']

# %%
dot.shape
# Out:
# (1250, 28)

# %%
# List of source DataFrames
dataframes = [df_standardized]
df_names = ["house"]

# Collect NA counts in each DataFrame
na_counts_data = []
for df, name in zip(dataframes, df_names):
    # Replace "na" text with NaN if needed
    df.replace("na", pd.NA, inplace=True)
    
    # Count NA values in each column
    na_counts = df.isna().sum()
    
    # Append results with the source DataFrame name
    for column, count in na_counts.items():
        na_counts_data.append([name, column, count])

# Create the summary DataFrame
na_counts_df = pd.DataFrame(na_counts_data, columns=["Listing Type", "Feature", "NA Count"])

na_counts_df
# Out:
#    Listing Type            Feature  NA Count
# 0         house              title         0
# 1         house         listing_id         0
# 2         house           bedrooms         0
# 3         house          bathrooms         0
# 4         house         floor_area         0
# 5         house          land_area         0
# 6         house          longitude         0
# 7         house           latitude         0
# 8         house                url         0
# 9         house              price         0
# 10        house        subdivision       285
# 11        house        description         0
# 12        house           Security         0
# 13        house              Alarm         0
# 14        house       Tennis court         0
# 15        house      Swimming pool         0
# 16        house            Balcony         0
# 17        house             Garden         0
# 18        house            Terrace         0
# 19        house    Children's area         0
# 20        house  Built-in wardrobe         0
# 21        house       Utility room         0
# 22        house           Car park         0
# 23        house   Air conditioning         0
# 24        house           Internet         0
# 25        house         facilities         0

# %%
# List of source DataFrames
dataframes = [dot]
df_names = ["house"]

# Collect NA counts in each DataFrame
na_counts_data = []
for df, name in zip(dataframes, df_names):
    # Replace "na" text with NaN if needed
    df.replace("na", pd.NA, inplace=True)
    
    # Count NA values in each column
    na_counts = df.isna().sum()
    
    # Append results with the source DataFrame name
    for column, count in na_counts.items():
        na_counts_data.append([name, column, count])

# Create the summary DataFrame
na_counts_df = pd.DataFrame(na_counts_data, columns=["Listing Type", "Feature", "NA Count"])

na_counts_df
# Out:
#    Listing Type            Feature  NA Count
# 0         house              title      1058
# 1         house           location         0
# 2         house              price         0
# 3         house                url         0
# 4         house         listing_id         0
# 5         house           bedrooms        64
# 6         house          bathrooms       105
# 7         house         floor_area         0
# 8         house          land_area        64
# 9         house              floor       649
# 10        house               name         0
# 11        house           latitude         0
# 12        house          longitude         0
# 13        house            address         2
# 14        house         facilities         0
# 15        house   Air conditioning         0
# 16        house              Alarm         0
# 17        house            Balcony         0
# 18        house  Built-in wardrobe         0
# 19        house           Car park         0
# 20        house    Children's area         0
# 21        house             Garden         0
# 22        house           Internet         0
# 23        house           Security         0
# 24        house      Swimming pool         0
# 25        house       Tennis court         0
# 26        house            Terrace         0
# 27        house       Utility room         0

# %%
# First, let's check the data types of these columns
print("Data types of the columns:")
print(df_standardized[['price', 'floor_area']].dtypes)

# Convert to numeric without string operations since they might already be numeric
df_standardized['price_per_sqm'] = pd.to_numeric(df_standardized['price']) / pd.to_numeric(df_standardized['floor_area'])

# Round to 2 decimal places
df_standardized['price_per_sqm'] = df_standardized['price_per_sqm'].round(2)

df_standardized.head()
# Out:
# Data types of the columns:
# price         float64
# floor_area      int64
# dtype: object
#                                                title         listing_id  \
# 0  Brand New House and Lot For Sale near New Mani...  HO66EE166652EAAPH
# 1  7.4 m Brand New SINGLE House and LOT in NEW HA...  HO677CA06D0F95FPH
# 2  5.1m Brand NEW 3 Bedrooms House and Lot Pre - ...  HO677CA7CB26D42PH
# 3  North Olympus Brand NEW House and LOT For Sale...  HO677CA41AA5555PH
# 4  CORNER LOT 3 Bedrooms Brand NEW House and LOT ...  HO677CA6A7554E4PH
#
#    bedrooms  bathrooms  floor_area  land_area   longitude   latitude  \
# 0         4          4         490        150  121.043543  14.613141
# 1         3          2          80        100  121.048350  14.733322
# 2         3          2          65         58  121.048350  14.733322
# 3         3          2          65        158  121.048350  14.733322
# 4         3          2          70         64  121.048350  14.733322
#
#                                                  url       price  ... Garden  \
# 0  https://www.lamudi.com.ph/buy/metro-manila/que...  65000000.0  ...      0
# 1  https://www.lamudi.com.ph/buy/metro-manila/que...   7400000.0  ...      0
# 2  https://www.lamudi.com.ph/buy/metro-manila/que...   5100000.0  ...      0
# 3  https://www.lamudi.com.ph/buy/metro-manila/que...   5100000.0  ...      1
# 4  https://www.lamudi.com.ph/buy/metro-manila/que...   5500000.0  ...      0
#
#   Terrace  Children's area  Built-in wardrobe  Utility room  Car park  \
# 0       0                0                  1             1         1
# 1       0                1                  0             0         1
# 2       0                1                  0             0         1
# 3       0                1                  0             0         1
# 4       0                1                  0             0         1
#
#    Air conditioning  Internet  facilities  price_per_sqm
# 0                 1         0           1      132653.06
# 1                 0         0           1       92500.00
# 2                 0         0           1       78461.54
# 3                 0         0           1       78461.54
# 4                 0         0           1       78571.43
#
# [5 rows x 27 columns]

# %%
# Drop rows where floor_area is null
dot = dot.dropna(subset=['floor_area'])

# %%
# Clean price column by removing ₱ symbol and commas, then convert to float
dot['price'] = dot['price'].str.replace('₱', '').str.replace(',', '').astype(float)

# Now create the price_per_sqm column
dot['price_per_sqm'] = dot['price'] / dot['floor_area']

# Round to 2 decimal places if desired
dot['price_per_sqm'] = dot['price_per_sqm'].round(2)

# %%
dot.shape
# Out:
# (1058, 29)

# %%
df_standardized.shape
# Out:
# (1500, 27)

# %%
# Vertical concatenation
combined_df = pd.concat([dot, df], axis=0, ignore_index=True)

# %%
combined_df.head()
# Out:
#    title                   location        price  \
# 0    NaN  Quezon City, Metro Manila  105000000.0
# 1    NaN  Quezon City, Metro Manila   86000000.0
# 2    NaN  Quezon City, Metro Manila    7600000.0
# 3    NaN  Quezon City, Metro Manila   38000000.0
# 4    NaN  Quezon City, Metro Manila   92000000.0
#
#                                                  url  \
# 0  https://www.dotproperty.com.ph/ads/5-bedroom-h...
# 1  https://www.dotproperty.com.ph/ads/5-bedroom-h...
# 2  https://www.dotproperty.com.ph/ads/4-bedroom-h...
# 3  https://www.dotproperty.com.ph/ads/4-bedroom-h...
# 4  https://www.dotproperty.com.ph/ads/5-bedroom-h...
#
#                              listing_id  bedrooms  bathrooms  floor_area  \
# 0                                 NFM01       5.0        5.0      427.62
# 1  0d1129d7-e3d9-4b66-9244-f77184ed6b36       5.0        5.0      500.00
# 2  01936167-0bde-7cc2-9513-321ba07d2da8       4.0        3.0      105.00
# 3  bce0e44d-c353-44be-a11a-d50e8be35eed       4.0        4.0      400.00
# 4  3ba5f401-31bc-4c19-b00c-e0a7b060b907       5.0        5.0      421.00
#
#   land_area  floor  ... Car park  Children's area  Garden Internet Security  \
# 0    500 m2    2.0  ...        1                0       1        0        0
# 1    441 m2    NaN  ...        1                1       0        1        0
# 2     35 m2    NaN  ...        1                0       1        0        0
# 3    314 m2    NaN  ...        0                0       0        0        1
# 4    400 m2    NaN  ...        1                0       0        0        1
#
#    Swimming pool  Tennis court  Terrace  Utility room  price_per_sqm
# 0              0             0        0             1      245545.11
# 1              0             0        0             0      172000.00
# 2              1             0        0             0       72380.95
# 3              0             0        0             0       95000.00
# 4              1             0        0             0      218527.32
#
# [5 rows x 29 columns]

# %%
# List of source DataFrames
dataframes = [combined_df]
df_names = ["house"]

# Collect NA counts in each DataFrame
na_counts_data = []
for df, name in zip(dataframes, df_names):
    # Replace "na" text with NaN if needed
    df.replace("na", pd.NA, inplace=True)
    
    # Count NA values in each column
    na_counts = df.isna().sum()
    
    # Append results with the source DataFrame name
    for column, count in na_counts.items():
        na_counts_data.append([name, column, count])

# Create the summary DataFrame
na_counts_df = pd.DataFrame(na_counts_data, columns=["Listing Type", "Feature", "NA Count"])

na_counts_df
# Out:
#    Listing Type            Feature  NA Count
# 0         house              title      2116
# 1         house           location         0
# 2         house              price         0
# 3         house                url         0
# 4         house         listing_id         0
# 5         house           bedrooms       128
# 6         house          bathrooms       210
# 7         house         floor_area         0
# 8         house          land_area       128
# 9         house              floor      1298
# 10        house               name         0
# 11        house           latitude         0
# 12        house          longitude         0
# 13        house            address         4
# 14        house         facilities         0
# 15        house   Air conditioning         0
# 16        house              Alarm         0
# 17        house            Balcony         0
# 18        house  Built-in wardrobe         0
# 19        house           Car park         0
# 20        house    Children's area         0
# 21        house             Garden         0
# 22        house           Internet         0
# 23        house           Security         0
# 24        house      Swimming pool         0
# 25        house       Tennis court         0
# 26        house            Terrace         0
# 27        house       Utility room         0
# 28        house      price_per_sqm         0

# %%
combined_df.to_csv("[jan 10] house listings.csv")
