# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from datetime import datetime
from typing import List, Dict, Optional
from dataclasses import dataclass, asdict
import json

# %% [markdown]
# ### House Scraping

# %%
@dataclass
class PropertyListing:
    """Data class to store property listing information"""
    title: str
    price: Optional[str] = None
    location: Optional[str] = None
    description: Optional[str] = None
    bedrooms: Optional[str] = None
    bathrooms: Optional[str] = None
    floor_area: Optional[str] = None
    land_size: Optional[str] = None
    property_type: Optional[str] = None
    subcategories: Optional[str] = None
    listing_url: Optional[str] = None
    listing_id: Optional[str] = None
    geo_location: Optional[str] = None
    car_spaces: Optional[str] = None
    classification: Optional[str] = None
    subdivision_name: Optional[str] = None

class LamudiScraper:
    """A class to scrape property listings from Lamudi Philippines"""
    
    BASE_URL = "https://www.lamudi.com.ph"
    
    def __init__(self):
        self.session = requests.Session()
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Language': 'en-US,en;q=0.5',
            'Referer': 'https://www.lamudi.com.ph'
        }
        self.session.headers.update(self.headers)

    def _extract_info(self, element: BeautifulSoup, class_name: str) -> str:
        """Helper method to extract text from HTML elements"""
        try:
            info = element.find(class_=class_name)
            return info.get_text(strip=True) if info else "N/A"
        except AttributeError:
            return "N/A"

    def _parse_data_attributes(self, listing_div) -> Dict:
        """Extract information from data attributes"""
        try:
            data = {
                'price': listing_div.get('data-price', 'N/A'),
                'subcategories': listing_div.get('data-subcategories', '[]'),
                'bedrooms': listing_div.get('data-bedrooms', 'N/A'),
                'bathrooms': listing_div.get('data-bathrooms', 'N/A'),
                'building_size': listing_div.get('data-building_size', 'N/A'),
                'land_size': listing_div.get('data-land_size', 'N/A'),
                'sku': listing_div.get('data-sku', 'N/A'),
                'geo_point': listing_div.get('data-geo-point', '[]'),
                'car_spaces': listing_div.get('data-car_spaces', 'N/A'),
                'classification': listing_div.get('data-classification', 'N/A'),
                'subdivision_name': listing_div.get('data-subdivisionname', 'N/A')
            }
            
            try:
                data['subcategories'] = ', '.join(json.loads(data['subcategories']))
            except json.JSONDecodeError:
                data['subcategories'] = 'N/A'
                
            return data
        except Exception as e:
            print(f"Error parsing data attributes: {e}")
            return {}

    def scrape_listings(self, url: str) -> List[PropertyListing]:
        """Scrape property listings from a page"""
        try:
            print(f"Scraping URL: {url}")
            response = self.session.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            
            listings = []
            listing_cells = soup.find_all('div', {'class': 'ListingCell-wrapper'})
            
            for cell in listing_cells:
                try:
                    listing_info_div = cell.find('div', {'class': 'ListingCell-AllInfo'})
                    if not listing_info_div:
                        continue
                        
                    data_attrs = self._parse_data_attributes(listing_info_div)
                    
                    title_elem = cell.find('h3', {'class': 'ListingCell-KeyInfo-title'})
                    title = title_elem.get_text(strip=True) if title_elem else "N/A"
                    
                    link_elem = cell.find('a', {'class': 'ListingCell-ListingLink'})
                    listing_url = f"{self.BASE_URL}{link_elem['href']}" if link_elem else None
                    
                    location = self._extract_info(cell, 'ListingCell-KeyInfo-address-text')
                    description = self._extract_info(cell, 'ListingCell-shortDescription')
                    
                    agent_info = cell.find('div', {'class': 'ListingDetail-agent-name'})
                    agent_name = agent_info.get_text(strip=True) if agent_info else "N/A"
                    
                    agency_info = cell.find('div', {'class': 'AgentInfoV2-agent-agency'})
                    agent_agency = agency_info.get_text(strip=True) if agency_info else "N/A"
                    
                    listings.append(PropertyListing(
                        title=title,
                        price=data_attrs.get('price', 'N/A'),
                        location=location,
                        description=description,
                        bedrooms=data_attrs.get('bedrooms', 'N/A'),
                        bathrooms=data_attrs.get('bathrooms', 'N/A'),
                        floor_area=data_attrs.get('building_size', 'N/A'),
                        land_size=data_attrs.get('land_size', 'N/A'),
                        listing_url=listing_url,
                        subcategories=data_attrs.get('subcategories', 'N/A'),
                        listing_id=data_attrs.get('sku', 'N/A'),
                        geo_location=data_attrs.get('geo_point', 'N/A'),
                        car_spaces=data_attrs.get('car_spaces', 'N/A'),
                        classification=data_attrs.get('classification', 'N/A'),
                        subdivision_name=data_attrs.get('subdivision_name', 'N/A')
                    ))
                    
                except Exception as e:
                    print(f"Error parsing listing: {e}")
                    continue
                
            return listings
            
        except requests.RequestException as e:
            print(f"Error fetching data: {e}")
            return []
        except Exception as e:
            print(f"Unexpected error: {e}")
            return []

    def save_to_csv(self, listings: List[PropertyListing], filename: Optional[str] = None):
        """Save the listings to a CSV file"""
        if not listings:
            print("No listings to save.")
            return
        
        if filename is None:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"lamudi_listings_{timestamp}.csv"
        
        listings_data = [asdict(listing) for listing in listings]
        df = pd.DataFrame(listings_data)
        df.to_csv(filename, index=False, encoding='utf-8-sig')
        print(f"Saved {len(listings)} listings to {filename}")

def main():
    """Example usage of the Lamudi Scraper"""
    scraper = LamudiScraper()
    url = "https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/"
    
    all_listings = []
    
    for page in range(1, 101):
        page_url = f"{url}?page={page}" if page > 1 else url
        print(f"Scraping page {page}...")
        
        listings = scraper.scrape_listings(page_url)
        if listings:
            all_listings.extend(listings)
            print(f"Found {len(listings)} listings on page {page}")
        else:
            print(f"No listings found on page {page}")
            break
            
        time.sleep(random.uniform(2, 4))
    
    if all_listings:
        scraper.save_to_csv(all_listings)
    
    print(f"\nTotal listings scraped: {len(all_listings)}")

if __name__ == "__main__":
    main()
# Out:
# Scraping page 1...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/
# Found 30 listings on page 1
# Scraping page 2...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=2
# Found 30 listings on page 2
# Scraping page 3...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=3
# Found 30 listings on page 3
# Scraping page 4...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=4
# Found 30 listings on page 4
# Scraping page 5...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=5
# Found 30 listings on page 5
# Scraping page 6...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=6
# Found 30 listings on page 6
# Scraping page 7...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=7
# Found 30 listings on page 7
# Scraping page 8...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=8
# Found 30 listings on page 8
# Scraping page 9...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=9
# Found 30 listings on page 9
# Scraping page 10...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=10
# Found 30 listings on page 10
# Scraping page 11...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=11
# Found 30 listings on page 11
# Scraping page 12...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=12
# Found 30 listings on page 12
# Scraping page 13...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=13
# Found 30 listings on page 13
# Scraping page 14...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=14
# Found 30 listings on page 14
# Scraping page 15...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=15
# Found 30 listings on page 15
# Scraping page 16...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=16
# Found 30 listings on page 16
# Scraping page 17...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=17
# Found 30 listings on page 17
# Scraping page 18...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=18
# Found 30 listings on page 18
# Scraping page 19...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=19
# Found 30 listings on page 19
# Scraping page 20...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=20
# Found 30 listings on page 20
# Scraping page 21...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=21
# Found 30 listings on page 21
# Scraping page 22...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=22
# Found 30 listings on page 22
# Scraping page 23...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=23
# Found 30 listings on page 23
# Scraping page 24...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=24
# Found 30 listings on page 24
# Scraping page 25...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=25
# Found 30 listings on page 25
# Scraping page 26...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=26
# Found 30 listings on page 26
# Scraping page 27...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=27
# Found 30 listings on page 27
# Scraping page 28...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=28
# Found 30 listings on page 28
# Scraping page 29...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=29
# Found 30 listings on page 29
# Scraping page 30...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=30
# Found 30 listings on page 30
# Scraping page 31...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=31
# Found 30 listings on page 31
# Scraping page 32...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=32
# Found 30 listings on page 32
# Scraping page 33...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=33
# Found 30 listings on page 33
# Scraping page 34...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=34
# Found 30 listings on page 34
# Scraping page 35...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=35
# Found 30 listings on page 35
# Scraping page 36...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=36
# Found 30 listings on page 36
# Scraping page 37...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=37
# Found 30 listings on page 37
# Scraping page 38...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=38
# Found 30 listings on page 38
# Scraping page 39...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=39
# Found 30 listings on page 39
# Scraping page 40...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=40
# Found 30 listings on page 40
# Scraping page 41...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=41
# Found 30 listings on page 41
# Scraping page 42...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=42
# Found 30 listings on page 42
# Scraping page 43...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=43
# Found 30 listings on page 43
# Scraping page 44...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=44
# Found 30 listings on page 44
# Scraping page 45...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=45
# Found 30 listings on page 45
# Scraping page 46...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=46
# Found 30 listings on page 46
# Scraping page 47...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=47
# Found 30 listings on page 47
# Scraping page 48...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=48
# Found 30 listings on page 48
# Scraping page 49...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=49
# Found 30 listings on page 49
# Scraping page 50...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=50
# Found 30 listings on page 50
# Scraping page 51...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=51
# Found 30 listings on page 51
# Scraping page 52...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=52
# Found 30 listings on page 52
# Scraping page 53...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=53
# Found 30 listings on page 53
# Scraping page 54...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=54
# Found 30 listings on page 54
# Scraping page 55...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=55
# Found 30 listings on page 55
# Scraping page 56...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=56
# Found 30 listings on page 56
# Scraping page 57...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=57
# Found 30 listings on page 57
# Scraping page 58...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=58
# Found 30 listings on page 58
# Scraping page 59...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=59
# Found 30 listings on page 59
# Scraping page 60...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=60
# Found 30 listings on page 60
# Scraping page 61...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=61
# Found 30 listings on page 61
# Scraping page 62...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=62
# Found 30 listings on page 62
# Scraping page 63...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=63
# Found 30 listings on page 63
# Scraping page 64...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=64
# Found 30 listings on page 64
# Scraping page 65...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=65
# Found 30 listings on page 65
# Scraping page 66...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=66
# Found 30 listings on page 66
# Scraping page 67...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=67
# Found 30 listings on page 67
# Scraping page 68...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=68
# Found 30 listings on page 68
# Scraping page 69...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=69
# Found 30 listings on page 69
# Scraping page 70...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=70
# Found 30 listings on page 70
# Scraping page 71...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=71
# Found 30 listings on page 71
# Scraping page 72...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=72
# Found 30 listings on page 72
# Scraping page 73...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=73
# Found 30 listings on page 73
# Scraping page 74...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=74
# Found 30 listings on page 74
# Scraping page 75...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=75
# Found 30 listings on page 75
# Scraping page 76...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=76
# Found 30 listings on page 76
# Scraping page 77...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=77
# Found 30 listings on page 77
# Scraping page 78...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=78
# Found 30 listings on page 78
# Scraping page 79...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=79
# Found 30 listings on page 79
# Scraping page 80...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=80
# Found 30 listings on page 80
# Scraping page 81...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=81
# Found 30 listings on page 81
# Scraping page 82...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=82
# Found 30 listings on page 82
# Scraping page 83...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=83
# Found 30 listings on page 83
# Scraping page 84...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=84
# Found 30 listings on page 84
# Scraping page 85...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=85
# Found 30 listings on page 85
# Scraping page 86...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=86
# Found 30 listings on page 86
# Scraping page 87...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=87
# Found 30 listings on page 87
# Scraping page 88...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=88
# Found 30 listings on page 88
# Scraping page 89...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=89
# Found 30 listings on page 89
# Scraping page 90...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=90
# Found 30 listings on page 90
# Scraping page 91...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=91
# Found 30 listings on page 91
# Scraping page 92...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=92
# Found 30 listings on page 92
# Scraping page 93...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=93
# Found 30 listings on page 93
# Scraping page 94...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=94
# Found 30 listings on page 94
# Scraping page 95...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=95
# Found 30 listings on page 95
# Scraping page 96...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=96
# Found 30 listings on page 96
# Scraping page 97...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=97
# Found 30 listings on page 97
# Scraping page 98...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=98
# Found 30 listings on page 98
# Scraping page 99...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=99
# Found 30 listings on page 99
# Scraping page 100...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/house/?page=100
# Found 30 listings on page 100
# Saved 3000 listings to lamudi_listings_20241120_063505.csv
#
# Total listings scraped: 3000

# %% [markdown]
# ### Apartment Scraping

# %%
@dataclass
class PropertyListing:
    """Data class to store property listing information"""
    title: str
    price: Optional[str] = None
    location: Optional[str] = None
    description: Optional[str] = None
    bedrooms: Optional[str] = None
    bathrooms: Optional[str] = None
    subcategories: Optional[str] = None
    rooms_total: Optional[str] = None
    floor_area: Optional[str] = None
    land_size: Optional[str] = None
    listing_url: Optional[str] = None
    listing_id: Optional[str] = None
    geo_location: Optional[str] = None
    car_spaces: Optional[str] = None
    classification: Optional[str] = None
    subdivision_name: Optional[str] = None

class LamudiScraper:
    """A class to scrape property listings from Lamudi Philippines"""
    
    BASE_URL = "https://www.lamudi.com.ph"
    
    def __init__(self):
        self.session = requests.Session()
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Language': 'en-US,en;q=0.5',
            'Referer': 'https://www.lamudi.com.ph'
        }
        self.session.headers.update(self.headers)

    def _extract_info(self, element: BeautifulSoup, class_name: str) -> str:
        """Helper method to extract text from HTML elements"""
        try:
            info = element.find(class_=class_name)
            return info.get_text(strip=True) if info else "N/A"
        except AttributeError:
            return "N/A"

    def _parse_data_attributes(self, listing_div) -> Dict:
        """Extract information from data attributes"""
        try:
            data = {
                'price': listing_div.get('data-price', 'N/A'),
                'bedrooms': listing_div.get('data-bedrooms', 'N/A'),
                'bathrooms': listing_div.get('data-bathrooms', 'N/A'),
                'rooms_total': listing_div.get('data-rooms_total', 'N/A'),
                'building_size': listing_div.get('data-building_size', 'N/A'),
                'land_size': listing_div.get('data-land_size', 'N/A'),
                'sku': listing_div.get('data-sku', 'N/A'),
                'geo_point': listing_div.get('data-geo-point', '[]'),
                'car_spaces': listing_div.get('data-car_spaces', 'N/A'),
                'subcategories': listing_div.get('data-subcategories', '[]'),
                'classification': listing_div.get('data-classification', 'N/A'),
                'subdivision_name': listing_div.get('data-subdivisionname', 'N/A')
            }
            
            try:
                data['subcategories'] = ', '.join(json.loads(data['subcategories']))
            except json.JSONDecodeError:
                data['subcategories'] = 'N/A'
                
            return data
        except Exception as e:
            print(f"Error parsing data attributes: {e}")
            return {}

    def scrape_listings(self, url: str) -> List[PropertyListing]:
        """Scrape property listings from a page"""
        try:
            print(f"Scraping URL: {url}")
            response = self.session.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            
            listings = []
            listing_cells = soup.find_all('div', {'class': 'ListingCell-wrapper'})
            
            for cell in listing_cells:
                try:
                    listing_info_div = cell.find('div', {'class': 'ListingCell-AllInfo'})
                    if not listing_info_div:
                        continue
                        
                    data_attrs = self._parse_data_attributes(listing_info_div)
                    
                    title_elem = cell.find('h3', {'class': 'ListingCell-KeyInfo-title'})
                    title = title_elem.get_text(strip=True) if title_elem else "N/A"
                    
                    link_elem = cell.find('a', {'class': 'ListingCell-ListingLink'})
                    listing_url = f"{self.BASE_URL}{link_elem['href']}" if link_elem else None
                    
                    location = self._extract_info(cell, 'ListingCell-KeyInfo-address-text')
                    description = self._extract_info(cell, 'ListingCell-shortDescription')
                    
                    agent_info = cell.find('div', {'class': 'ListingDetail-agent-name'})
                    agent_name = agent_info.get_text(strip=True) if agent_info else "N/A"
                    
                    agency_info = cell.find('div', {'class': 'AgentInfoV2-agent-agency'})
                    agent_agency = agency_info.get_text(strip=True) if agency_info else "N/A"
                    
                    listings.append(PropertyListing(
                        title=title,
                        price=data_attrs.get('price', 'N/A'),
                        location=location,
                        description=description,
                        bedrooms=data_attrs.get('bedrooms', 'N/A'),
                        bathrooms=data_attrs.get('bathrooms', 'N/A'),
                        rooms_total=data_attrs.get('rooms_total', 'N/A'),
                        floor_area=data_attrs.get('building_size', 'N/A'),
                        land_size=data_attrs.get('land_size', 'N/A'),
                        listing_url=listing_url,
                        listing_id=data_attrs.get('sku', 'N/A'),
                        subcategories=data_attrs.get('subcategories', 'N/A'),
                        geo_location=data_attrs.get('geo_point', 'N/A'),
                        car_spaces=data_attrs.get('car_spaces', 'N/A'),
                        classification=data_attrs.get('classification', 'N/A'),
                        subdivision_name=data_attrs.get('subdivision_name', 'N/A')
                    ))
                    
                except Exception as e:
                    print(f"Error parsing listing: {e}")
                    continue
                
            return listings
            
        except requests.RequestException as e:
            print(f"Error fetching data: {e}")
            return []
        except Exception as e:
            print(f"Unexpected error: {e}")
            return []

    def save_to_csv(self, listings: List[PropertyListing], filename: Optional[str] = None):
        """Save the listings to a CSV file"""
        if not listings:
            print("No listings to save.")
            return
        
        if filename is None:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"lamudi_listings_{timestamp}.csv"
        
        listings_data = [asdict(listing) for listing in listings]
        df = pd.DataFrame(listings_data)
        df.to_csv(filename, index=False, encoding='utf-8-sig')
        print(f"Saved {len(listings)} listings to {filename}")

def main():
    """Example usage of the Lamudi Scraper"""
    scraper = LamudiScraper()
    url = "https://www.lamudi.com.ph/buy/metro-manila/quezon-city/apartment/"
    
    all_listings = []
    
    for page in range(1, 4):
        page_url = f"{url}?page={page}" if page > 1 else url
        print(f"Scraping page {page}...")
        
        listings = scraper.scrape_listings(page_url)
        if listings:
            all_listings.extend(listings)
            print(f"Found {len(listings)} listings on page {page}")
        else:
            print(f"No listings found on page {page}")
            break
            
        time.sleep(random.uniform(2, 4))
    
    if all_listings:
        scraper.save_to_csv(all_listings)
        
    
    print(f"\nTotal listings scraped: {len(all_listings)}")

if __name__ == "__main__":
    main()
# Out:
# Scraping page 1...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/apartment/
# Found 30 listings on page 1
# Scraping page 2...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/apartment/?page=2
# Found 30 listings on page 2
# Scraping page 3...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/apartment/?page=3
# Found 12 listings on page 3
# Saved 72 listings to lamudi_listings_20241120_064959.csv
#
# Total listings scraped: 72

# %% [markdown]
# ### Condo Scraping

# %%
@dataclass
class PropertyListing:
    """Data class to store property listing information"""
    title: str
    price: Optional[str] = None
    location: Optional[str] = None
    description: Optional[str] = None
    bedrooms: Optional[str] = None
    bathrooms: Optional[str] = None
    rooms_total: Optional[str] = None
    floor_area: Optional[str] = None
    land_size: Optional[str] = None
    listing_url: Optional[str] = None
    listing_id: Optional[str] = None
    geo_location: Optional[str] = None
    car_spaces: Optional[str] = None
    classification: Optional[str] = None
    condominium_name: Optional[str] = None 

class LamudiScraper:
    """A class to scrape property listings from Lamudi Philippines"""
    
    BASE_URL = "https://www.lamudi.com.ph"
    
    def __init__(self):
        self.session = requests.Session()
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Language': 'en-US,en;q=0.5',
            'Referer': 'https://www.lamudi.com.ph'
        }
        self.session.headers.update(self.headers)

    def _extract_info(self, element: BeautifulSoup, class_name: str) -> str:
        """Helper method to extract text from HTML elements"""
        try:
            info = element.find(class_=class_name)
            return info.get_text(strip=True) if info else "N/A"
        except AttributeError:
            return "N/A"

    def _parse_data_attributes(self, listing_div) -> Dict:
        """Extract information from data attributes"""
        try:
            data = {
                'price': listing_div.get('data-price', 'N/A'),
                'category': listing_div.get('data-category', 'N/A'),
                'subcategories': listing_div.get('data-subcategories', '[]'),
                'bedrooms': listing_div.get('data-bedrooms', 'N/A'),
                'bathrooms': listing_div.get('data-bathrooms', 'N/A'),
                'building_size': listing_div.get('data-building_size', 'N/A'),
                'sku': listing_div.get('data-sku', 'N/A'),
                'geo_point': listing_div.get('data-geo-point', '[]'),
                'furnished': listing_div.get('data-furnished', 'N/A'),
                'classification': listing_div.get('data-classification', 'N/A'),
                'condominium_name': listing_div.get('data-condominiumname', 'N/A')
            }
            
            try:
                data['subcategories'] = ', '.join(json.loads(data['subcategories']))
            except json.JSONDecodeError:
                data['subcategories'] = 'N/A'
                
            return data
        except Exception as e:
            print(f"Error parsing data attributes: {e}")
            return {}

    def scrape_listings(self, url: str) -> List[PropertyListing]:
        """Scrape property listings from a page"""
        try:
            print(f"Scraping URL: {url}")
            response = self.session.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            
            listings = []
            listing_cells = soup.find_all('div', {'class': 'ListingCell-wrapper'})
            
            for cell in listing_cells:
                try:
                    listing_info_div = cell.find('div', {'class': 'ListingUnit'})
                    if not listing_info_div:
                        continue
                        
                    data_attrs = self._parse_data_attributes(listing_info_div)
                    
                    # Find the listing link and title
                    link_elem = cell.find('a', {'class': 'ListingCell-ListingLink'})
                    title = link_elem.get('title', 'N/A') if link_elem else 'N/A'
                    listing_url = f"{self.BASE_URL}{link_elem['href']}" if link_elem else None
                    
                    # Extract location from title or separate element if available
                    location = self._extract_info(cell, 'ListingCell-KeyInfo-address-text')
                    if location == 'N/A' and title != 'N/A':
                        # Try to extract location from title
                        location = title.split(' in ')[-1] if ' in ' in title else 'N/A'
                    
                    description = self._extract_info(cell, 'ListingCell-shortDescription')
                    
                    listings.append(PropertyListing(
                        title=title,
                        price=data_attrs.get('price', 'N/A'),
                        location=location,
                        description=description,
                        bedrooms=data_attrs.get('bedrooms', 'N/A'),
                        bathrooms=data_attrs.get('bathrooms', 'N/A'),
                        floor_area=data_attrs.get('building_size', 'N/A'),
                        listing_url=listing_url,
                        listing_id=data_attrs.get('sku', 'N/A'),
                        geo_location=data_attrs.get('geo_point', 'N/A'),
                        classification=data_attrs.get('classification', 'N/A'),
                        condominium_name=data_attrs.get('condominium_name', 'N/A')
                    ))
                    
                except Exception as e:
                    print(f"Error parsing listing: {e}")
                    continue
                
            return listings
            
        except requests.RequestException as e:
            print(f"Error fetching data: {e}")
            return []
        except Exception as e:
            print(f"Unexpected error: {e}")
            return []

    def save_to_csv(self, listings: List[PropertyListing], filename: Optional[str] = None):
        """Save the listings to a CSV file"""
        if not listings:
            print("No listings to save.")
            return
        
        if filename is None:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"lamudi_listings_{timestamp}.csv"
        
        listings_data = [asdict(listing) for listing in listings]
        df = pd.DataFrame(listings_data)
        df.to_csv(filename, index=False, encoding='utf-8-sig')
        print(f"Saved {len(listings)} listings to {filename}")

def main():
    """Example usage of the Lamudi Scraper"""
    scraper = LamudiScraper()
    url = "https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/"
    
    all_listings = []
    
    for page in range(1, 101):
        page_url = f"{url}?page={page}" if page > 1 else url
        print(f"Scraping page {page}...")
        
        listings = scraper.scrape_listings(page_url)
        if listings:
            all_listings.extend(listings)
            print(f"Found {len(listings)} listings on page {page}")
        else:
            print(f"No listings found on page {page}")
            break
            
        time.sleep(random.uniform(2, 4))
    
    if all_listings:
        scraper.save_to_csv(all_listings)

    
    print(f"\nTotal listings scraped: {len(all_listings)}")

if __name__ == "__main__":
    main()
# Out:
# Scraping page 1...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/
# Found 30 listings on page 1
# Scraping page 2...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=2
# Found 30 listings on page 2
# Scraping page 3...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=3
# Found 30 listings on page 3
# Scraping page 4...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=4
# Found 30 listings on page 4
# Scraping page 5...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=5
# Found 30 listings on page 5
# Scraping page 6...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=6
# Found 30 listings on page 6
# Scraping page 7...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=7
# Found 30 listings on page 7
# Scraping page 8...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=8
# Found 30 listings on page 8
# Scraping page 9...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=9
# Found 30 listings on page 9
# Scraping page 10...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=10
# Found 30 listings on page 10
# Scraping page 11...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=11
# Found 30 listings on page 11
# Scraping page 12...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=12
# Found 30 listings on page 12
# Scraping page 13...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=13
# Found 30 listings on page 13
# Scraping page 14...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=14
# Found 30 listings on page 14
# Scraping page 15...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=15
# Found 30 listings on page 15
# Scraping page 16...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=16
# Found 30 listings on page 16
# Scraping page 17...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=17
# Found 30 listings on page 17
# Scraping page 18...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=18
# Found 30 listings on page 18
# Scraping page 19...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=19
# Found 30 listings on page 19
# Scraping page 20...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=20
# Found 30 listings on page 20
# Scraping page 21...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=21
# Found 30 listings on page 21
# Scraping page 22...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=22
# Found 30 listings on page 22
# Scraping page 23...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=23
# Found 30 listings on page 23
# Scraping page 24...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=24
# Found 30 listings on page 24
# Scraping page 25...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=25
# Found 30 listings on page 25
# Scraping page 26...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=26
# Found 30 listings on page 26
# Scraping page 27...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=27
# Found 30 listings on page 27
# Scraping page 28...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=28
# Found 30 listings on page 28
# Scraping page 29...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=29
# Found 30 listings on page 29
# Scraping page 30...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=30
# Found 30 listings on page 30
# Scraping page 31...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=31
# Found 30 listings on page 31
# Scraping page 32...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=32
# Found 30 listings on page 32
# Scraping page 33...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=33
# Found 30 listings on page 33
# Scraping page 34...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=34
# Found 30 listings on page 34
# Scraping page 35...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=35
# Found 30 listings on page 35
# Scraping page 36...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=36
# Found 30 listings on page 36
# Scraping page 37...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=37
# Found 30 listings on page 37
# Scraping page 38...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=38
# Found 30 listings on page 38
# Scraping page 39...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=39
# Found 30 listings on page 39
# Scraping page 40...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=40
# Found 30 listings on page 40
# Scraping page 41...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=41
# Found 30 listings on page 41
# Scraping page 42...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=42
# Found 30 listings on page 42
# Scraping page 43...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=43
# Found 30 listings on page 43
# Scraping page 44...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=44
# Found 30 listings on page 44
# Scraping page 45...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=45
# Found 30 listings on page 45
# Scraping page 46...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=46
# Found 30 listings on page 46
# Scraping page 47...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=47
# Found 30 listings on page 47
# Scraping page 48...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=48
# Found 30 listings on page 48
# Scraping page 49...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=49
# Found 30 listings on page 49
# Scraping page 50...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=50
# Found 30 listings on page 50
# Scraping page 51...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=51
# Found 30 listings on page 51
# Scraping page 52...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=52
# Found 30 listings on page 52
# Scraping page 53...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=53
# Found 30 listings on page 53
# Scraping page 54...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=54
# Found 30 listings on page 54
# Scraping page 55...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=55
# Found 30 listings on page 55
# Scraping page 56...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=56
# Found 30 listings on page 56
# Scraping page 57...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=57
# Found 30 listings on page 57
# Scraping page 58...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=58
# Found 30 listings on page 58
# Scraping page 59...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=59
# Found 30 listings on page 59
# Scraping page 60...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=60
# Found 30 listings on page 60
# Scraping page 61...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=61
# Found 30 listings on page 61
# Scraping page 62...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=62
# Found 30 listings on page 62
# Scraping page 63...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=63
# Found 30 listings on page 63
# Scraping page 64...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=64
# Found 30 listings on page 64
# Scraping page 65...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=65
# Found 30 listings on page 65
# Scraping page 66...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=66
# Found 30 listings on page 66
# Scraping page 67...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=67
# Found 30 listings on page 67
# Scraping page 68...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=68
# Found 30 listings on page 68
# Scraping page 69...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=69
# Found 30 listings on page 69
# Scraping page 70...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=70
# Found 30 listings on page 70
# Scraping page 71...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=71
# Found 30 listings on page 71
# Scraping page 72...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=72
# Found 30 listings on page 72
# Scraping page 73...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=73
# Found 30 listings on page 73
# Scraping page 74...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=74
# Found 30 listings on page 74
# Scraping page 75...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=75
# Found 30 listings on page 75
# Scraping page 76...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=76
# Found 30 listings on page 76
# Scraping page 77...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=77
# Found 30 listings on page 77
# Scraping page 78...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=78
# Found 30 listings on page 78
# Scraping page 79...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=79
# Found 30 listings on page 79
# Scraping page 80...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=80
# Found 30 listings on page 80
# Scraping page 81...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=81
# Found 30 listings on page 81
# Scraping page 82...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=82
# Found 30 listings on page 82
# Scraping page 83...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=83
# Found 30 listings on page 83
# Scraping page 84...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=84
# Found 30 listings on page 84
# Scraping page 85...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=85
# Found 30 listings on page 85
# Scraping page 86...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=86
# Found 30 listings on page 86
# Scraping page 87...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=87
# Found 30 listings on page 87
# Scraping page 88...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=88
# Found 30 listings on page 88
# Scraping page 89...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=89
# Found 30 listings on page 89
# Scraping page 90...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=90
# Found 30 listings on page 90
# Scraping page 91...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=91
# Found 30 listings on page 91
# Scraping page 92...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=92
# Found 30 listings on page 92
# Scraping page 93...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=93
# Found 30 listings on page 93
# Scraping page 94...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=94
# Found 30 listings on page 94
# Scraping page 95...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=95
# Found 30 listings on page 95
# Scraping page 96...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=96
# Found 30 listings on page 96
# Scraping page 97...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=97
# Found 30 listings on page 97
# Scraping page 98...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=98
# Found 30 listings on page 98
# Scraping page 99...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=99
# Found 30 listings on page 99
# Scraping page 100...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/condo/?page=100
# Found 30 listings on page 100
# Saved 3000 listings to lamudi_listings_20241120_064038.csv
#
# Total listings scraped: 3000

# %% [markdown]
# ### Commercial Scraping

# %%
from dataclasses import dataclass, asdict
from typing import List, Dict, Optional
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
from datetime import datetime
import time
import random

@dataclass
class PropertyListing:
    """Data class to store property listing information"""
    title: str
    price: Optional[str] = None
    location: Optional[str] = None
    description: Optional[str] = None
    bedrooms: Optional[str] = None
    bathrooms: Optional[str] = None
    floor_area: Optional[str] = None
    property_type: Optional[str] = None
    subcategories: Optional[str] = None
    listing_url: Optional[str] = None
    listing_id: Optional[str] = None
    geo_location: Optional[str] = None
    furnished_status: Optional[str] = None
    condominium_name: Optional[str] = None
    is_new_development: Optional[bool] = None

class LamudiScraper:
    """A class to scrape property listings from Lamudi Philippines"""
    
    BASE_URL = "https://www.lamudi.com.ph"
    
    def __init__(self):
        self.session = requests.Session()
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Language': 'en-US,en;q=0.5',
            'Referer': 'https://www.lamudi.com.ph'
        }
        self.session.headers.update(self.headers)

    def _extract_info(self, element: BeautifulSoup, class_name: str) -> str:
        """Helper method to extract text from HTML elements"""
        try:
            info = element.find(class_=class_name)
            return info.get_text(strip=True) if info else "N/A"
        except AttributeError:
            return "N/A"

    def _parse_data_attributes(self, listing_div) -> Dict:
        """Extract information from data attributes based on the new HTML structure"""
        try:
            data = {
                'price': listing_div.get('data-price', 'N/A'),
                'category': listing_div.get('data-category', 'N/A'),
                'subcategories': listing_div.get('data-subcategories', '[]'),
                'classification': listing_div.get('data-classification', 'N/A'),
                'furnished': listing_div.get('data-furnished', 'N/A'),
                'bedrooms': listing_div.get('data-bedrooms', 'N/A'),
                'bathrooms': listing_div.get('data-bathrooms', 'N/A'),
                'building_size': listing_div.get('data-building_size', 'N/A'),
                'condominiumname': listing_div.get('data-condominiumname', 'N/A'),
                'sku': listing_div.get('data-sku', 'N/A'),
                'geo_point': listing_div.get('data-geo-point', '[]'),
                'is_new_development': listing_div.get('data-listing-new-development', 'false')
            }
            
            # Parse subcategories JSON array
            try:
                data['subcategories'] = ', '.join(json.loads(data['subcategories']))
            except json.JSONDecodeError:
                data['subcategories'] = 'N/A'
            
            # Parse geo_point JSON array
            try:
                geo_point = json.loads(data['geo_point'])
                data['geo_point'] = f"{geo_point[0]}, {geo_point[1]}"
            except json.JSONDecodeError:
                data['geo_point'] = 'N/A'
            
            # Convert is_new_development to boolean
            data['is_new_development'] = data['is_new_development'].lower() == 'true'
                
            return data
        except Exception as e:
            print(f"Error parsing data attributes: {e}")
            return {}

    def scrape_listings(self, url: str) -> List[PropertyListing]:
        """Scrape property listings from a page"""
        try:
            print(f"Scraping URL: {url}")
            response = self.session.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            
            listings = []
            listing_cells = soup.find_all('div', {'class': 'ListingCell-wrapper'})
            
            for cell in listing_cells:
                try:
                    listing_info_div = cell.find('div', {'class': 'ListingCell-AllInfo'})
                    if not listing_info_div:
                        continue
                        
                    data_attrs = self._parse_data_attributes(listing_info_div)
                    
                    # Extract image information
                    img_elem = cell.find('img')
                    title = img_elem.get('alt', 'N/A') if img_elem else "N/A"
                    
                    # Extract listing URL
                    link_elem = cell.find('a', {'class': 'ListingCell-ListingLink'})
                    listing_url = f"{self.BASE_URL}{link_elem['href']}" if link_elem else None
                    
                    # Extract other information
                    location = self._extract_info(cell, 'ListingCell-KeyInfo-address-text')
                    description = self._extract_info(cell, 'ListingCell-shortDescription')
                    
                    listings.append(PropertyListing(
                        title=title,
                        price=data_attrs.get('price', 'N/A'),
                        location=location,
                        description=description,
                        bedrooms=data_attrs.get('bedrooms', 'N/A'),
                        bathrooms=data_attrs.get('bathrooms', 'N/A'),
                        floor_area=data_attrs.get('building_size', 'N/A'),
                        property_type=data_attrs.get('category', 'N/A'),
                        subcategories=data_attrs.get('subcategories', 'N/A'),
                        listing_url=listing_url,
                        listing_id=data_attrs.get('sku', 'N/A'),
                        geo_location=data_attrs.get('geo_point', 'N/A'),
                        furnished_status=data_attrs.get('furnished', 'N/A'),
                        condominium_name=data_attrs.get('condominiumname', 'N/A'),
                        is_new_development=data_attrs.get('is_new_development', False)
                    ))
                    
                except Exception as e:
                    print(f"Error parsing listing: {e}")
                    continue
                
            return listings
            
        except requests.RequestException as e:
            print(f"Error fetching data: {e}")
            return []
        except Exception as e:
            print(f"Unexpected error: {e}")
            return []

    def save_to_csv(self, listings: List[PropertyListing], filename: Optional[str] = None):
        """Save the listings to a CSV file"""
        if not listings:
            print("No listings to save.")
            return
        
        if filename is None:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"lamudi_listings_{timestamp}.csv"
        
        listings_data = [asdict(listing) for listing in listings]
        df = pd.DataFrame(listings_data)
        df.to_csv(filename, index=False, encoding='utf-8-sig')
        print(f"Saved {len(listings)} listings to {filename}")

def main():
    """Example usage of the Lamudi Scraper"""
    scraper = LamudiScraper()
    url = "https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/"
    
    all_listings = []
    
    for page in range(1, 50):
        page_url = f"{url}?page={page}" if page > 1 else url
        print(f"Scraping page {page}...")
        
        listings = scraper.scrape_listings(page_url)
        if listings:
            all_listings.extend(listings)
            print(f"Found {len(listings)} listings on page {page}")
        else:
            print(f"No listings found on page {page}")
            break
            
        time.sleep(random.uniform(2, 4))  # Polite delay between requests
    
    if all_listings:
        scraper.save_to_csv(all_listings)
    
    print(f"\nTotal listings scraped: {len(all_listings)}")

if __name__ == "__main__":
    main()
# Out:
# Scraping page 1...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/
# Found 30 listings on page 1
# Scraping page 2...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=2
# Found 30 listings on page 2
# Scraping page 3...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=3
# Found 30 listings on page 3
# Scraping page 4...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=4
# Found 30 listings on page 4
# Scraping page 5...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=5
# Found 30 listings on page 5
# Scraping page 6...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=6
# Found 30 listings on page 6
# Scraping page 7...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=7
# Found 30 listings on page 7
# Scraping page 8...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=8
# Found 30 listings on page 8
# Scraping page 9...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=9
# Found 30 listings on page 9
# Scraping page 10...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=10
# Found 30 listings on page 10
# Scraping page 11...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=11
# Found 30 listings on page 11
# Scraping page 12...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=12
# Found 30 listings on page 12
# Scraping page 13...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=13
# Found 30 listings on page 13
# Scraping page 14...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=14
# Found 30 listings on page 14
# Scraping page 15...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=15
# Found 30 listings on page 15
# Scraping page 16...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=16
# Found 30 listings on page 16
# Scraping page 17...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=17
# Found 30 listings on page 17
# Scraping page 18...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=18
# Found 30 listings on page 18
# Scraping page 19...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=19
# Found 30 listings on page 19
# Scraping page 20...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=20
# Found 30 listings on page 20
# Scraping page 21...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=21
# Found 30 listings on page 21
# Scraping page 22...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=22
# Found 14 listings on page 22
# Scraping page 23...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=23
# Found 30 listings on page 23
# Scraping page 24...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=24
# Found 30 listings on page 24
# Scraping page 25...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=25
# Found 30 listings on page 25
# Scraping page 26...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=26
# Found 30 listings on page 26
# Scraping page 27...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=27
# Found 30 listings on page 27
# Scraping page 28...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=28
# Found 30 listings on page 28
# Scraping page 29...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=29
# Found 30 listings on page 29
# Scraping page 30...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=30
# Found 30 listings on page 30
# Scraping page 31...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=31
# Found 30 listings on page 31
# Scraping page 32...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=32
# Found 30 listings on page 32
# Scraping page 33...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=33
# Found 30 listings on page 33
# Scraping page 34...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=34
# Found 30 listings on page 34
# Scraping page 35...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=35
# Found 30 listings on page 35
# Scraping page 36...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=36
# Found 30 listings on page 36
# Scraping page 37...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=37
# Found 30 listings on page 37
# Scraping page 38...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=38
# Found 30 listings on page 38
# Scraping page 39...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=39
# Found 30 listings on page 39
# Scraping page 40...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=40
# Found 30 listings on page 40
# Scraping page 41...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=41
# Found 30 listings on page 41
# Scraping page 42...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=42
# Found 30 listings on page 42
# Scraping page 43...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=43
# Found 30 listings on page 43
# Scraping page 44...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=44
# Found 30 listings on page 44
# Scraping page 45...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=45
# Found 30 listings on page 45
# Scraping page 46...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=46
# Found 30 listings on page 46
# Scraping page 47...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=47
# Found 30 listings on page 47
# Scraping page 48...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=48
# Found 30 listings on page 48
# Scraping page 49...
# Scraping URL: https://www.lamudi.com.ph/buy/metro-manila/quezon-city/commercial/?page=49
# Found 30 listings on page 49
# Saved 1454 listings to lamudi_listings_20241120_064347.csv
#
# Total listings scraped: 1454
