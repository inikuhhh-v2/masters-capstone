# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np

from pandas import NA

import re #

# %% [markdown]
# ## Loading the dataset

# %%
condo = pd.read_csv("[nov 26] dot_condo.csv")

# %%
condo.shape
# Out:
# (1250, 51)

# %% [markdown]
# ## Data cleaning
#
#  - Check for NA values.
#      - Perform text analysis to possibly obtain NA values from listing description.
#  - Drop irrelevant columns.

# %%
# List of source DataFrames
dataframes = [condo]
df_names = ["condominium"]

# Collect NA counts in each DataFrame
na_counts_data = []
for df, name in zip(dataframes, df_names):
    # Replace "na" text with NaN if needed
    df.replace("na", pd.NA, inplace=True)
    
    # Count NA values in each column
    na_counts = df.isna().sum()
    
    # Append results with the source DataFrame name
    for column, count in na_counts.items():
        na_counts_data.append([name, column, count])

# Create the summary DataFrame
na_counts_df = pd.DataFrame(na_counts_data, columns=["Listing Type", "Feature", "NA Count"])

na_counts_df
# Out:
#    Listing Type                           Feature  NA Count
# 0   condominium                             title         0
# 1   condominium                             price         0
# 2   condominium                     price_per_sqm        11
# 3   condominium                          location      1250
# 4   condominium                       description         0
# 5   condominium                          bedrooms       218
# 6   condominium                         bathrooms         9
# 7   condominium                        floor_area         9
# 8   condominium                      floor_number       388
# 9   condominium                     property_type         0
# 10  condominium                       listing_url         2
# 11  condominium                        agent_name         0
# 12  condominium                       agency_name      1250
# 13  condominium                          latitude         2
# 14  condominium                         longitude         2
# 15  condominium                    facility_grill         0
# 16  condominium  facility_access_for_the_disabled         0
# 17  condominium                 facility_security         0
# 18  condominium                    facility_alarm         0
# 19  condominium        facility_built-in_wardrobe         0
# 20  condominium                   facility_garden         0
# 21  condominium                  facility_hot_tub         0
# 22  condominium              facility_roof_garden         0
# 23  condominium              facility_video_cable         0
# 24  condominium                  facility_cistern         0
# 25  condominium             facility_tennis_court         0
# 26  condominium            facility_swimming_pool         0
# 27  condominium                 facility_car_park         0
# 28  condominium                    facility_sauna         0
# 29  condominium                 facility_elevator         0
# 30  condominium                   facility_office         0
# 31  condominium              facility_natural_gas         0
# 32  condominium           facility_panoramic_view         0
# 33  condominium               facility_guardhouse         0
# 34  condominium          facility_children's_area         0
# 35  condominium                facility_fireplace         0
# 36  condominium                   facility_cellar         0
# 37  condominium                  facility_heating         0
# 38  condominium             facility_utility_room         0
# 39  condominium                  facility_library         0
# 40  condominium         facility_equipped_kitchen         0
# 41  condominium                      facility_gym         0
# 42  condominium                facility_concierge         0
# 43  condominium                  facility_terrace         0
# 44  condominium         facility_built-in_kitchen         0
# 45  condominium         facility_air_conditioning         0
# 46  condominium                 facility_internet         0
# 47  condominium                  facility_balcony         0
# 48  condominium              facility_electricity         0
# 49  condominium                    facility_patio         0
# 50  condominium                    facility_water         0

# %%
# Remove duplicate rows and irrelevant columns
condo = condo.replace({pd.NA: NA, np.nan: NA, 'NaN': NA})
condo = condo.drop_duplicates()
condo = condo.drop(columns = ["location", "agency_name"])

# First, replace NA values in bedrooms with 0
condo['bedrooms'] = condo['bedrooms'].fillna(0)

# Drop rows where longitude OR latitude is NA
condo = condo.dropna(subset=['longitude', 'latitude'])

# %%
condo.shape
# Out:
# (1242, 49)

# %%
def extract_floor_info(description):
    # Initialize variables to store extracted values
    floor_number = None
    floor_area = None
    bathrooms = None
    
    # Convert to lowercase for easier matching
    desc = str(description).lower()
    
    # Extract floor number
    floor_patterns = [
        r'(\d+)(?:st|nd|rd|th)\s+floor',
        r'(?:on\s+)?(?:the\s+)?(\d+)(?:st|nd|rd|th)?(?:\s+)?(?:floor|flr)',
        r'floor\s*-\s*(\d+)',
        r'level\s*-?\s*(\d+)'
    ]
    
    for pattern in floor_patterns:
        match = re.search(pattern, desc)
        if match:
            floor_number = int(match.group(1))
            break
    
    # Extract floor area
    area_patterns = [
        r'(\d+(?:\.\d+)?)\s*(?:sqm|sq\.?\s*m|square\s*meters?)',
        r'floor\s*area\s*:?\s*(\d+(?:\.\d+)?)',
        r'area\s*:?\s*(\d+(?:\.\d+)?)\s*sqm',
        r'(\d+(?:\.\d+)?)\s*m2'
    ]
    
    for pattern in area_patterns:
        match = re.search(pattern, desc)
        if match:
            floor_area = float(match.group(1))
            break
    
    # Extract number of bathrooms
    bathroom_patterns = [
        r'(\d+)\s*(?:bathroom|bath|t&b|toilet|tb|t & b)',
        r'(\d+)\s*(?:cr|comfort room)',
        r'bath(?:room)?s?\s*:?\s*(\d+)'
    ]
    
    for pattern in bathroom_patterns:
        match = re.search(pattern, desc)
        if match:
            bathrooms = float(match.group(1))
            break
            
    return pd.Series({
        'floor_number': floor_number,
        'floor_area': floor_area,
        'bathrooms': bathrooms
    })

def fill_missing_values(df):
    # Create mask for rows with missing values
    floor_number_mask = df['floor_number'].isna()
    floor_area_mask = df['floor_area'].isna()
    bathrooms_mask = df['bathrooms'].isna()
    
    # Extract information from descriptions where values are missing
    extracted_info = df[floor_number_mask | floor_area_mask | bathrooms_mask]['description'].apply(extract_floor_info)
    
    # Update only the missing values with extracted information
    df.loc[floor_number_mask, 'floor_number'] = extracted_info[floor_number_mask]['floor_number']
    df.loc[floor_area_mask, 'floor_area'] = extracted_info[floor_area_mask]['floor_area']
    df.loc[bathrooms_mask, 'bathrooms'] = extracted_info[bathrooms_mask]['bathrooms']
    
    return df

# %%
condo = fill_missing_values(condo)
# Out:
# /var/folders/8n/jrsz__p10dz9_525b42ylv1c0000gn/T/ipykernel_41064/963913764.py:70: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[floor_number_mask, 'floor_number'] = extracted_info[floor_number_mask]['floor_number']
# /var/folders/8n/jrsz__p10dz9_525b42ylv1c0000gn/T/ipykernel_41064/963913764.py:71: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[floor_area_mask, 'floor_area'] = extracted_info[floor_area_mask]['floor_area']
# /var/folders/8n/jrsz__p10dz9_525b42ylv1c0000gn/T/ipykernel_41064/963913764.py:72: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[bathrooms_mask, 'bathrooms'] = extracted_info[bathrooms_mask]['bathrooms']

# %%
# List of source DataFrames
dataframes = [condo]
df_names = ["condominium"]

# Collect NA counts in each DataFrame
na_counts_data = []
for df, name in zip(dataframes, df_names):
    # Replace "na" text with NaN if needed
    df.replace("na", pd.NA, inplace=True)
    
    # Count NA values in each column
    na_counts = df.isna().sum()
    
    # Append results with the source DataFrame name
    for column, count in na_counts.items():
        na_counts_data.append([name, column, count])

# Create the summary DataFrame
na_counts_df = pd.DataFrame(na_counts_data, columns=["Listing Type", "Feature", "NA Count"])

na_counts_df
# Out:
#    Listing Type                           Feature  NA Count
# 0   condominium                             title         0
# 1   condominium                             price         0
# 2   condominium                     price_per_sqm        11
# 3   condominium                       description         0
# 4   condominium                          bedrooms         0
# 5   condominium                         bathrooms         9
# 6   condominium                        floor_area         8
# 7   condominium                      floor_number       361
# 8   condominium                     property_type         0
# 9   condominium                       listing_url         0
# 10  condominium                        agent_name         0
# 11  condominium                          latitude         0
# 12  condominium                         longitude         0
# 13  condominium                    facility_grill         0
# 14  condominium  facility_access_for_the_disabled         0
# 15  condominium                 facility_security         0
# 16  condominium                    facility_alarm         0
# 17  condominium        facility_built-in_wardrobe         0
# 18  condominium                   facility_garden         0
# 19  condominium                  facility_hot_tub         0
# 20  condominium              facility_roof_garden         0
# 21  condominium              facility_video_cable         0
# 22  condominium                  facility_cistern         0
# 23  condominium             facility_tennis_court         0
# 24  condominium            facility_swimming_pool         0
# 25  condominium                 facility_car_park         0
# 26  condominium                    facility_sauna         0
# 27  condominium                 facility_elevator         0
# 28  condominium                   facility_office         0
# 29  condominium              facility_natural_gas         0
# 30  condominium           facility_panoramic_view         0
# 31  condominium               facility_guardhouse         0
# 32  condominium          facility_children's_area         0
# 33  condominium                facility_fireplace         0
# 34  condominium                   facility_cellar         0
# 35  condominium                  facility_heating         0
# 36  condominium             facility_utility_room         0
# 37  condominium                  facility_library         0
# 38  condominium         facility_equipped_kitchen         0
# 39  condominium                      facility_gym         0
# 40  condominium                facility_concierge         0
# 41  condominium                  facility_terrace         0
# 42  condominium         facility_built-in_kitchen         0
# 43  condominium         facility_air_conditioning         0
# 44  condominium                 facility_internet         0
# 45  condominium                  facility_balcony         0
# 46  condominium              facility_electricity         0
# 47  condominium                    facility_patio         0
# 48  condominium                    facility_water         0
